# %% [markdown]
# # Week 12 HW Tidy Census Data

# %%
import pandas as pd

# %%
df = pd.read_csv("census.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            129 non-null    object
#  1   state fips       129 non-null    int64
#  2   commodity        129 non-null    object
#  3   data item        129 non-null    object
#  4   domain category  15 non-null     object
#  5   2017             127 non-null    object
#  6   2012             124 non-null    object
#  7   2007             124 non-null    object
#  8   2002             124 non-null    object
#  9   1997             117 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 10.2+ KB

# %%
df.sample(10)
# Out:
#         state  state fips         commodity  \
# 78   US TOTAL          99             WHEAT
# 32   US TOTAL          99  COMMODITY TOTALS
# 103  US TOTAL          99     HAY & HAYLAGE
# 8    US TOTAL          99   FARM OPERATIONS
# 29   US TOTAL          99  COMMODITY TOTALS
# 85   US TOTAL          99           SORGHUM
# 105  US TOTAL          99     HAY & HAYLAGE
# 84   US TOTAL          99            BARLEY
# 43   US TOTAL          99          INTEREST
# 83   US TOTAL          99            BARLEY
#
#                                              data item  \
# 78          WHEAT, WINTER - PRODUCTION, MEASURED IN BU
# 32            COMMODITY TOTALS - OPERATIONS WITH SALES
# 103     HAY & HAYLAGE - OPERATIONS WITH AREA HARVESTED
# 8                     FARM OPERATIONS - ACRES OPERATED
# 29            COMMODITY TOTALS - OPERATIONS WITH SALES
# 85     SORGHUM, GRAIN - OPERATIONS WITH AREA HARVESTED
# 105  HAY & HAYLAGE - PRODUCTION, MEASURED IN TONS, ...
# ...

# %%
df = df.rename(columns={"data item": "description"})
df.drop(["state", "state fips"], axis=1, inplace=True)

# %%
df
# Out:
#            commodity                                        description  \
# 0    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ..               ...                                                ...
# 124         POTATOES                         POTATOES - ACRES HARVESTED
# 125   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 126   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 127         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 128         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#                          domain category       2017       2012       2007  \
# ...

# %%
melted_df = df.melt(id_vars=["commodity","description", "domain category"],
                   var_name = "year",
                   value_name = "us_totals")
melted_df
# Out:
#            commodity                                        description  \
# 0    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ..               ...                                                ...
# 640         POTATOES                         POTATOES - ACRES HARVESTED
# 641   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 642   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 643         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 644         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#                          domain category  year  us_totals
# ...

# %%
melted_df.drop(["a", "b"], axis=1)
melted_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cd/ptcktmld0_15yrknc99vw6480000gn/T/ipykernel_56593/1830368095.py in <module>
# ----> 1 melted_df.drop(["a", "b"], axis=1)
#       2 melted_df
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...
